# %%
import os,json

# %%
existingNodes = []
rule_output = []
links = []
logical_rule = "("  #Else it is arithmetic rule
negated = "~"

def output_data():
    test = rule_output.reverse()
    with open('node.json', 'w') as df:
        json.dump(rule_output, df, indent = 4)

    with open('link.json', 'w') as df:
        json.dump(links,df, indent = 4)


likes_Obs = {}
unobservedAtoms = []
unobVal = {}
def find_unobserved_atoms():
    with open('data/KNOWS.txt', 'r') as target:
        for line in target:
            constants = line.strip().split("\t")
            unobserved = 'KNOWS(' + constants[0] + ', ' +constants[1]+ ')'
            
            unobVal[unobserved] = constants[2]
#             print(unobserved, constants[2])
            unobservedAtoms.append(unobserved)
    
    with open('data/likes_obs.txt', 'r') as target:
        for line in target:
            constants = line.strip().split("\t")
            unobserved = 'LIKES(' + "'" + constants[0] + "'"+ ', ' + "'"+constants[1]+"'"+ ')'
            print(unobserved)
            likes_Obs[unobserved] = constants[2]

        
#Finding predicates to split into groups for coloring
def findPredicates():
    with open('simple-acquaintances.data', 'r') as data:
        predicate = {}
        data = data.read().strip()
        data = data.split("\n\n")

        predicates = data[0].split('\n')[1:]
        i = 1;
        for pred in predicates:
          
            open_closed = pred.split(':')[1].strip()  #Finding open / closed predicate
            pred = pred.strip().split('/')  #Finding predicate name
            predicate[pred[0].upper()] = [i, open_closed]
            i+=1
                    
    return predicate    



#Finding links and atoms for logical rule
def findLogicalRules(rules, Group, satisfaction):
    groundAtoms = []  #List containing the ground atoms
    rules = rules[1:-1] #Getting rid of the first and last parenthesis
    rules = rules.strip()
    groundRules = rules.split(" | ")
    
    
    
    num_unobserved = 0
 #Grabbing each ground atom
    for atoms in groundRules:
     
        # If ground atom has negation in front, parse out and just grab the ground atom within
        if atoms[0] == negated:
            groundAtom = atoms[3:-2]  # Obtain the ground atom for negated atoms
        else:
            groundAtom = atoms

        predicate_group = groundAtom.split("(")[0]  #Getting the predicate and making it "case insensitive"
#         print(predicate_group)
        if groundAtom not in existingNodes:
            
            atom_data = {'groundAtom': groundAtom, 'group': Group[predicate_group][0], 'type': Group[predicate_group][1]}
            # Adding oberved / unobserved parameter
            if groundAtom in unobservedAtoms:
                atom_data['value'] = unobVal[groundAtom]
                atom_data['unobserved'] = True
                num_unobserved +=1  # Keeping track of number of unobserved atoms in the rule
            else:
                if predicate_group == 'LIKES':
                    print('HERE')
                    atom_data['value'] = likes_Obs[groundAtom]
                else:
                    atom_data['value'] = 1
                atom_data['unobserved'] = False
            
            rule_output.append(atom_data)
            
            existingNodes.append(groundAtom)
        
        groundAtoms.append(groundAtom)
   

    if num_unobserved > 1 :
        links.append({'source': groundAtoms[0], 'target': groundAtoms[1], 'rule': rules, 'satisfaction': satisfaction})
        links.append({'source': groundAtoms[0], 'target': groundAtoms[2], 'rule': rules, 'satisfaction': satisfaction}) 
        links.append({'source': groundAtoms[1], 'target': groundAtoms[2], 'rule': rules, 'satisfaction': satisfaction})
        
    else:
        if groundAtoms[0] in unobservedAtoms:
            links.append({'source': groundAtoms[1], 'target': groundAtoms[0], 'rule': rules, 'satisfaction': satisfaction})
            links.append({'source': groundAtoms[2], 'target': groundAtoms[0], 'rule': rules, 'satisfaction': satisfaction}) 
        elif groundAtoms[1] in unobservedAtoms:
            links.append({'source': groundAtoms[0], 'target': groundAtoms[1], 'rule': rules, 'satisfaction': satisfaction})
            links.append({'source': groundAtoms[2], 'target': groundAtoms[1], 'rule': rules, 'satisfaction': satisfaction}) 
        else:
            links.append({'source': groundAtoms[1], 'target': groundAtoms[2], 'rule': rules, 'satisfaction': satisfaction})
            links.append({'source': groundAtoms[0], 'target': groundAtoms[2], 'rule': rules, 'satisfaction': satisfaction}) 
                                                                  
                                                                  


with open('data/sat.txt', 'r') as data:
    find_unobserved_atoms()
    predicateGroup = findPredicates()       #Getting predicate node group 
    for line in data:
        line = line.strip()
        data_split = line.split("\t")
        
#         print(data_split[3])
        satisfaction = data_split[3]
        rules = data_split[2]
        
        #Just for logical rule links
        if rules[0] == logical_rule:
            findLogicalRules(rules, predicateGroup, satisfaction)
            

output_data()
# Out:
# LIKES('Elena', 'Machine Learning')
# LIKES('Jay', 'Machine Learning')
# LIKES('Steve', 'Machine Learning')
# LIKES('Ben', 'Machine Learning')
# LIKES('Alex', 'Machine Learning')
# LIKES('Arti', 'Machine Learning')
# LIKES('Dhanya', 'Machine Learning')
# LIKES('Sabina', 'Machine Learning')
# LIKES('Jay', 'Skeeball')
# LIKES('Steve', 'Skeeball')
# LIKES('Ben', 'Skeeball')
# LIKES('Jay', 'Trivia')
# LIKES('Steve', 'Trivia')
# LIKES('Sabina', 'Trivia')
# LIKES('Steve', 'Sports')
# LIKES('Ben', 'Sports')
# LIKES('Alex', 'Veggies')
# LIKES('Jay', 'Veggies')
# LIKES('Sabina', 'Veggies')
# LIKES('Arti', 'Veggies')
# LIKES('Dhanya', 'Veggies')
# LIKES('Steve', 'Veggies')
# LIKES('Elena', 'Veggies')
# LIKES('Ben', 'Veggies')
# LIKES('Jay', 'Climbing')
# LIKES('Sabina', 'Climbing')
# LIKES('Dhanya', 'Climbing')
# LIKES('Arti', 'Education')
# LIKES('Sabina', 'Education')
# LIKES('Ben', 'Hiking')
# LIKES('Dhanya', 'Hiking')
# LIKES('Steve', 'Hiking')
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE
# HERE

# %%
# Out:
# KNOWS('Elena', 'Steve')
# KNOWS('Elena', 'Jay')
# KNOWS('Elena', 'Ben')
# KNOWS('Elena', 'Alex')
# KNOWS('Elena', 'Arti')
# KNOWS('Elena', 'Dhanya')
# KNOWS('Elena', 'Sabina')
# KNOWS('Steve', 'Elena')
# KNOWS('Steve', 'Jay')
# KNOWS('Steve', 'Ben')
# KNOWS('Steve', 'Alex')
# KNOWS('Steve', 'Arti')
# KNOWS('Steve', 'Dhanya')
# KNOWS('Steve', 'Sabina')
# KNOWS('Jay', 'Elena')
# KNOWS('Jay', 'Steve')
# KNOWS('Jay', 'Ben')
# KNOWS('Jay', 'Alex')
# KNOWS('Jay', 'Arti')
# KNOWS('Jay', 'Dhanya')
# KNOWS('Jay', 'Sabina')
# KNOWS('Ben', 'Steve')
# KNOWS('Ben', 'Jay')
# KNOWS('Ben', 'Alex')
# KNOWS('Ben', 'Arti')
# KNOWS('Ben', 'Sabina')
# KNOWS('Alex', 'Elena')
# KNOWS('Alex', 'Steve')
# KNOWS('Alex', 'Jay')
# KNOWS('Alex', 'Ben')
# KNOWS('Alex', 'Arti')
# KNOWS('Alex', 'Dhanya')
# KNOWS('Alex', 'Sabina')
# KNOWS('Arti', 'Elena')
# KNOWS('Arti', 'Steve')
# KNOWS('Arti', 'Jay')
# KNOWS('Arti', 'Ben')
# KNOWS('Arti', 'Dhanya')
# KNOWS('Arti', 'Sabina')
# KNOWS('Dhanya', 'Elena')
# KNOWS('Dhanya', 'Steve')
# KNOWS('Dhanya', 'Jay')
# KNOWS('Dhanya', 'Ben')
# KNOWS('Dhanya', 'Alex')
# KNOWS('Dhanya', 'Arti')
# KNOWS('Dhanya', 'Sabina')
# KNOWS('Sabina', 'Elena')
# KNOWS('Sabina', 'Steve')
# KNOWS('Sabina', 'Jay')
# KNOWS('Sabina', 'Ben')
# KNOWS('Sabina', 'Alex')
# KNOWS('Sabina', 'Arti')
